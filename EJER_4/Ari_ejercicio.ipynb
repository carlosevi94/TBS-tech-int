# %%
import pandas as pd

# %%
df = pd.read_csv("train.csv", sep=",")

# %%
df.head()
# Out:
#    Number                    title               artist        top genre  \
# 0     175     She Looks So Perfect  5 Seconds of Summer         boy band
# 1     577               Run To You          Bryan Adams       album rock
# 2     275             Stuck On You        Lionel Richie  adult standards
# 3     514  The Rhythm of the Night               Corona  bubblegum dance
# 4     300          Beautiful Girls        Sean Kingston        dance pop
#
#    year  bpm  nrgy  dnce  dB  live  val  dur  acous  spch  pop
# 0  2014  160    95    49  -4    33   44  202      0    13   69
# 1  1984  127    81    56  -6    29   64  233      1     3   65
# 2  1983  132    32    51 -16     9   25  192     62     3   69
# 3  1994  128    81    69 -12    10   80  264      0     3   69
# 4  2014  118    64    54  -7    24   75  242     14     9   60

# %%
df.info
# Out:
# <bound method DataFrame.info of      Number                      title                artist  \
# 0       175       She Looks So Perfect   5 Seconds of Summer
# 1       577                 Run To You           Bryan Adams
# 2       275               Stuck On You         Lionel Richie
# 3       514    The Rhythm of the Night                Corona
# 4       300            Beautiful Girls         Sean Kingston
# ..      ...                        ...                   ...
# 381     162  Guilty (feat. Barry Gibb)      Barbra Streisand
# 382     558         Please Mr. Postman       The Marvelettes
# 383     568  Hypnotize - 2007 Remaster  The Notorious B.I.G.
# 384     292            The Way We Were      Barbra Streisand
# 385     126                 In the End           Linkin Park
#
#               top genre  year  bpm  nrgy  dnce  dB  live  val  dur  acous  \
# 0              boy band  2014  160    95    49  -4    33   44  202      0
# ...

# %%
media = df.groupby("title")[["dur"]].sum().mean()

# %%
media
# Out:
# dur    235.3
# dtype: float64

# %%
df["cancion_larga"] = df.dur > df.dur.mean()

# %%
df.head()
# Out:
#    Number                    title               artist        top genre  \
# 0     175     She Looks So Perfect  5 Seconds of Summer         boy band
# 1     577               Run To You          Bryan Adams       album rock
# 2     275             Stuck On You        Lionel Richie  adult standards
# 3     514  The Rhythm of the Night               Corona  bubblegum dance
# 4     300          Beautiful Girls        Sean Kingston        dance pop
#
#    year  bpm  nrgy  dnce  dB  live  val  dur  acous  spch  pop  cancion_larga
# 0  2014  160    95    49  -4    33   44  202      0    13   69          False
# 1  1984  127    81    56  -6    29   64  233      1     3   65           True
# 2  1983  132    32    51 -16     9   25  192     62     3   69          False
# 3  1994  128    81    69 -12    10   80  264      0     3   69           True
# 4  2014  118    64    54  -7    24   75  242     14     9   60           True

# %% [markdown]
# SQL
#
# SELECT title, IF (dur > AVG(dur), 1, 0) AS VALIDACION FROM df
